# %% [markdown]
# # ICS3U Python Programming Evaluation 1
#
# ## Instructions
#
# In the final part of ICS3U Grade 11 Computer Science course you are going to do a little bit of research involving artificial intelligence and its applications
#
# <details>
# <summary>Overall Expectations Being Evaluated</summary>
#
# D1 – Environmental Stewardship
#
# - Describe how computer science concepts can be used to improve problematic environmental issues
#
# D2 – Exploring Computer Science
#
# - Demonstrate an understanding of an emergent area of computer science
#
# D3 – Post Secondary Opportunities
#
# - Demonstrate an understanding of important skills and educational requirements for computer science careers
# </details>

# %% [markdown]
# <br>
#
# # Part 1 – AI in Modern Media
#
# In this section you are going to demonstrate your understanding of Strong and Weak AI and the the Turing Test
#
# Humanity often uses the arts and story telling to reflect on important issues to society and answer question about who we are and where the future will take us. The concept or artificial intelligence has greatly captured human interest over the last century. Many stories explore how to determine if a machine is intelligent, and whether to extend rights of beings with Artificial Intelligence.
#
# We want to look at the use of AI in Books and Movies and TV Shows.   Pick a movie / Book / Game that illustrates some type of AI Character.  You can pick anything but some examples are:  (Ex Machina, Data (Star Trek TNG), IRobot, A.I., 2001: A Space Oddessy, 9, WALL-E, Interstellar, etc )
#
# Write a report / essay (500 to 1000 words) with your thoughts to the following :
#
# - Summarize the character and story. How did the AI character come into existence?
#
# - What is its purpose? How do the AI and other characters relate to each other?
#
# - Does the character consider themselves to be intelligent? Do the other characters?
#
# - Discuss how tests of Artificial Intelligence are conducted or can be conducted in this story.
#
# - How successful would the Turing Test be in determining whether this AI is truly artificial intelligence?
#
# - Is this character an example of weak AI or strong AI?

# %%
interstellar
The movie interstellar take place in the future, when earth drying from dust storms and food shortag. 
A group go to the space A group of astronauts travels through a wormhole to find a new planet for humans to live on. The main character, Cooper, goes on the mission with scientist Amelia Brand and two AI robots, TARS and CASE.

TARS is a tall, rectangular robot made of metal panels that move and spin in creative ways. It doesn’t look human, but it can talk, make jokes, and think on its own. TARS was built by NASA to help with space missions and protect the crew.

Purpose and Relationships
TARS’s main purpose is to help the astronauts complete their mission safely. It can control the ship, make quick calculations, and even sacrifice itself to save the humans. The astronauts start off unsure about trusting it, but over time, TARS proves it’s dependable and loyal.

The crew treats TARS like a teammate, not just a machine. It understands humor, honesty, and even friendship. This shows how AI can form strong relationships with humans when built with empathy and care.

Does TARS Think It’s Intelligent?
TARS doesn’t say directly that it’s intelligent, but it clearly acts like it is. It understands emotions, makes choices, and speaks naturally. The humans see it as intelligent too—they talk to it like a person and rely on its judgment. Even though TARS doesn’t “feel” emotions the same way humans do, it understands them well enough to show kindness and humor.

AI Testing and the Turing Test
The Turing Test, created by scientist Alan Turing, checks if a machine can “think.” If a human talks to a machine and can’t tell it’s a machine, the AI passes the test.

In Interstellar, TARS would likely pass the Turing Test. Its voice, humor, and problem-solving skills make it seem human-like. If someone talked to TARS without seeing it, they might think they were talking to a person. However, TARS still follows its programming and doesn’t truly feel emotions, so the Turing Test might not show its full intelligence.

Weak AI or Strong AI
TARS is an example of strong AI. Weak AI can only do one task, like a calculator or search engine, but strong AI can think and make decisions. TARS shows strong AI because it reasons, adapts, and understands human behavior. It doesn’t just follow orders—it acts creatively and makes moral choices.

# %% [markdown]
# <br>
#
# # Part 2 – Careers and Education
#
# Research career choices in computer science (Any Field, doesn’t need to be AI) in your area, Canada, and internationally. Compare wages, and other statistics. Choose one job advertisement that could interest you as a possible career and include it in your assignment.
#
# 1. Why did you choose this job?
#
# 2. What education is needed for this job. Find a University/College program where you can get the required education. What are the prerequisites for the program?
#
# 3. Is experience needed for this job? Research ways to gain experience in this field: co-op, internship, volunteering, mentoring, job shadowing etc. Explain a specific way you could gain experience.
#
# 4. Find the essential skills needed for the job from your advertisement. Do you have these skills? Are there any skills that you need to develop further?

# %%
1.I think this job will be intersting
2.grade 12 math Most game programming jobs require a Bachelor’s degree in Computer Science or Game Development.
A good program for this is the Honours Bachelor of Game Design at Sheridan College in Ontario.
3.Yes, experience is usually needed. Most studios look for people who have made their own games or worked on small projects.
4.Programming in C# or C++
	•	Experience with Unity or Unreal Engine
	•	Problem-solving and teamwork
	•	Creativity and attention to detail

# %% [markdown]
# <br>
#
# # Part 3 – Environmental Issues
#
# In 1 – 2 paragraphs
#
# - How can AI be used to improve problematic environmental issues facing society

# %%
AI can help the environment by tracking and solving problems like pollution, climate change, and deforestation. It can analyze data to predict weather, monitor air and water quality, and manage energy use more efficiently. AI also helps make farming, recycling, and transportation systems smarter and less wasteful, leading to a cleaner and more sustainable planet.
